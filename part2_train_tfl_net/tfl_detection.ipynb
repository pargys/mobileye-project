# %% [markdown]
# ## Hands on lecture: train TFL net
#
#  In this hands-on lecture, we will train a model for predicting Traffic-light (TFL) in image patches, you will use the data generated in previous course to this end.
#  You will :
#  1. Evaluate the data previously generated and ensure it's validity.
#  2. Train a CNN
#  3. Evaluate results of the trained model.
#  4. seek ways to improve results

# %%
# %reload_ext autoreload
# %autoreload 2
# %autosave 120
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
from os.path import join

# %% [markdown]
# ## Step 1. Validate your data
#     use the example in the cell below, to verify the TFL patch you've generated is sane.
#     Things to watch for:
#     1. You are able to load and vizualize your train and val data, using the functions below.
#     2. using the vizualization verify  image <--> label correspondence is correct.
#     3. % Negative vs. Positive examples is aprroximately 50%

# %%
def load_tfl_data(data_dir, crop_shape=(81,81)):
    images = np.memmap(join(data_dir,'data.bin'),mode='r',dtype=np.uint8).reshape([-1]+list(crop_shape) +[3])
    labels = np.memmap(join(data_dir,'labels.bin'),mode='r',dtype=np.uint8)
    return {'images':images,'labels':labels}

def viz_my_data(images,labels, predictions=None, num=(5,5), labels2name= {0:'No TFL',1:'Yes TFL'}):
    assert images.shape[0] == labels.shape[0]
    assert predictions is None or predictions.shape[0] == images.shape[0]
    h = 5
    n = num[0]*num[1]
    ax = plt.subplots(num[0],num[1],figsize=(h*num[0],h*num[1]),gridspec_kw={'wspace':0.05},squeeze=False,sharex=True,sharey=True)[1]#.flatten()
    idxs = np.random.randint(0,images.shape[0],n)
    for i,idx in enumerate(idxs):
        ax.flatten()[i].imshow(images[idx])
        title = labels2name[labels[idx]]
        if predictions is not None : title += ' Prediction: {:.2f}'.format(predictions[idx])
        ax.flatten()[i].set_title(title)
   

# root = './'  #this is the root for your val and train datasets
data_dir = '../correct_data'
datasets = {
    'val':load_tfl_data(join(data_dir,'val')),
    'train': load_tfl_data(join(data_dir,'train')),
    }
for k,v in datasets.items():
    
    print ('{} :  {} 0/1 split {:.1f} %'.format(k,v['images'].shape, np.mean(v['labels']==1)*100))

viz_my_data(num=(6,6),**datasets['val'])
# Out:
# val :  (1332, 81, 81, 3) 0/1 split 50.0 %
# train :  (8124, 81, 81, 3) 0/1 split 50.0 %

# %% [markdown]
# ## define the model used for training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, MaxPooling2D, Dense, Dropout, Flatten, Activation,MaxPooling2D,BatchNormalization,Activation, Conv2D

def tfl_model():
    input_shape =(81,81,3)
    
    model = Sequential()
    def conv_bn_relu(filters,**conv_kw):
        model.add(Conv2D(filters,  use_bias=True, kernel_initializer='he_normal',**conv_kw, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        
    def dense_bn_relu(units):
        model.add(Dense(units, use_bias=True, kernel_initializer='he_normal'))
#         model.add(Dropout(0.5))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
    
    def spatial_layer(count, filters): 
        for i in range(count):
            conv_bn_relu(filters,kernel_size=(3,3))
        conv_bn_relu(filters, kernel_size=(3,3),strides=(2,2))
    
    conv_bn_relu(32,kernel_size=(3,3),input_shape=input_shape)
    spatial_layer(1,32) 
    spatial_layer(2,64)
    spatial_layer(2,96)
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
    
    
    model.add(Flatten())
    dense_bn_relu(96)
    model.add(Dense(2, activation='softmax'))
    return model
m = tfl_model()
m.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 81, 81, 32)        896
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 81, 81, 32)        128
# _________________________________________________________________
# activation_20 (Activation)   (None, 81, 81, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 81, 81, 32)        9248
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 81, 81, 32)        128
# _________________________________________________________________
# activation_21 (Activation)   (None, 81, 81, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 41, 41, 32)        9248
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 41, 41, 32)        128
# _________________________________________________________________
# activation_22 (Activation)   (None, 41, 41, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 41, 41, 64)        18496
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 41, 41, 64)        256
# _________________________________________________________________
# activation_23 (Activation)   (None, 41, 41, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 41, 41, 64)        36928
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 41, 41, 64)        256
# _________________________________________________________________
# activation_24 (Activation)   (None, 41, 41, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# activation_25 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 21, 21, 96)        55392
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 21, 21, 96)        384
# _________________________________________________________________
# activation_26 (Activation)   (None, 21, 21, 96)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 96)        83040
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 21, 21, 96)        384
# _________________________________________________________________
# activation_27 (Activation)   (None, 21, 21, 96)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 11, 11, 96)        83040
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 11, 11, 96)        384
# _________________________________________________________________
# activation_28 (Activation)   (None, 11, 11, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 96)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 96)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2400)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 96)                230496
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 96)                384
# _________________________________________________________________
# activation_29 (Activation)   (None, 96)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 194
# =================================================================
# Total params: 566,594
# Trainable params: 565,250
# Non-trainable params: 1,344
# _________________________________________________________________

# %% [markdown]
# ## train

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
data_dir = '../correct_data'
datasets = {
    'val':load_tfl_data(join(data_dir,'val')),
    'train': load_tfl_data(join(data_dir,'train')),
    }

# dark_data_dir = 'dark_data'
# dark_data_set = {'train':  load_tfl_data(join(dark_data_dir,'train'))}

# flip_data_dir = 'flip_data'
# flip_data_set = {'train':  load_tfl_data(join(flip_data_dir,'train'))}

#prepare our model
m = tfl_model()
m.compile(optimizer=Adam(),loss =sparse_categorical_crossentropy,metrics=['accuracy'])

train,val = datasets['train'],datasets['val']
# train it, the model uses the 'train' dataset for learning. We evaluate the "goodness" of the model, by predicting the label of the images in the val dataset.

history=m.fit(train['images'], train['labels'],validation_data=(val['images'],val['labels']),epochs = 10) 

# history=m.fit(dark_data_set['train']['images'], dark_data_set['train']['labels'],validation_data=(val['images'],val['labels']),epochs = 5, batch_size = 400) 

# history=m.fit(flip_data_set['train']['images'], flip_data_set['train']['labels'],validation_data=(val['images'],val['labels']),epochs = 10, batch_size = 400) 
# history=m.fit(my_flip_data_set['train']['images'], my_flip_data_set['train']['labels'],validation_data=(val['images'],val['labels']),epochs = 10)
# Out:
# Train on 8124 samples, validate on 1332 samples
# Epoch 1/10
# 8124/8124 [==============================] - 781s 96ms/sample - loss: 0.4247 - acc: 0.7862 - val_loss: 0.4265 - val_acc: 0.7793
# Epoch 2/10
# 8124/8124 [==============================] - 733s 90ms/sample - loss: 0.3163 - acc: 0.8560 - val_loss: 0.2885 - val_acc: 0.8784
# Epoch 3/10
# 8124/8124 [==============================] - 572s 70ms/sample - loss: 0.2789 - acc: 0.8808 - val_loss: 0.5175 - val_acc: 0.7725
# Epoch 4/10
# 8124/8124 [==============================] - 573s 70ms/sample - loss: 0.2544 - acc: 0.8925 - val_loss: 0.3431 - val_acc: 0.8506
# Epoch 5/10
# 8124/8124 [==============================] - 575s 71ms/sample - loss: 0.2391 - acc: 0.8932 - val_loss: 0.2888 - val_acc: 0.8791
# Epoch 6/10
# 8124/8124 [==============================] - 567s 70ms/sample - loss: 0.2198 - acc: 0.9079 - val_loss: 0.4090 - val_acc: 0.8326
# Epoch 7/10
# 8124/8124 [==============================] - 619s 76ms/sample - loss: 0.1990 - acc: 0.9152 - val_loss: 0.2618 - val_acc: 0.8889
# Epoch 8/10
# 8124/8124 [==============================] - 553s 68ms/sample - loss: 0.1925 - acc: 0.9185 - val_loss: 0.2848 - val_acc: 0.8716
# Epoch 9/10
# 8124/8124 [==============================] - 502s 62ms/sample - loss: 0.1752 - acc: 0.9264 - val_loss: 0.2647 - val_acc: 0.8881
# Epoch 10/10
# 8124/8124 [==============================] - 501s 62ms/sample - loss: 0.1581 - acc: 0.9357 - val_loss: 0.2895 - val_acc: 0.8746

# %%
history=m.fit(train['images'], train['labels'],validation_data=(val['images'],val['labels']),epochs = 10)
# Out:
# Train on 8124 samples, validate on 1332 samples
# Epoch 1/10
# 8124/8124 [==============================] - 683s 84ms/sample - loss: 0.1510 - acc: 0.9401 - val_loss: 0.2574 - val_acc: 0.9039
# Epoch 2/10
# 8124/8124 [==============================] - 503s 62ms/sample - loss: 0.1397 - acc: 0.9445 - val_loss: 0.3345 - val_acc: 0.8739
# Epoch 3/10
# 8124/8124 [==============================] - 501s 62ms/sample - loss: 0.1302 - acc: 0.9508 - val_loss: 0.6655 - val_acc: 0.7973
# Epoch 4/10
# 8124/8124 [==============================] - 500s 62ms/sample - loss: 0.1202 - acc: 0.9541 - val_loss: 0.2675 - val_acc: 0.9017
# Epoch 5/10
# 8124/8124 [==============================] - 503s 62ms/sample - loss: 0.1083 - acc: 0.9574 - val_loss: 0.3237 - val_acc: 0.8949
# Epoch 6/10
# 8124/8124 [==============================] - 500s 62ms/sample - loss: 0.0990 - acc: 0.9627 - val_loss: 0.2558 - val_acc: 0.9017
# Epoch 7/10
# 8124/8124 [==============================] - 500s 62ms/sample - loss: 0.1044 - acc: 0.9584 - val_loss: 0.2846 - val_acc: 0.8851
# Epoch 8/10
# 8124/8124 [==============================] - 499s 61ms/sample - loss: 0.0748 - acc: 0.9702 - val_loss: 0.4841 - val_acc: 0.8514
# Epoch 9/10
# 8124/8124 [==============================] - 500s 61ms/sample - loss: 0.0762 - acc: 0.9687 - val_loss: 0.2802 - val_acc: 0.9024
# Epoch 10/10
# 8124/8124 [==============================] - 502s 62ms/sample - loss: 0.0842 - acc: 0.9687 - val_loss: 0.3661 - val_acc: 0.8844

# %%
# history=m.fit(train['images'], train['labels'],validation_data=(val['images'],val['labels']),epochs = 5)

# %%
# my_flip_data_dir = 'my_flip_big_data'
# my_flip_data_set = { 'train':  load_tfl_data(join(my_flip_data_dir,'train'))}
                    
# history=m.fit(my_flip_data_set['train']['images'], my_flip_data_set['train']['labels'],validation_data=(val['images'],val['labels']),epochs = 10)

# %%
#compare train vs val acccuracy, 
# why is val_accuracy not as good as train accuracy? are we overfitting?
epochs = history.history
epochs['train_acc'] = epochs['acc']
plt.figure(figsize=(10,10))
for k in ['train_acc','val_acc']:
    plt.plot(range(len(epochs[k])), epochs[k],label=k)

plt.legend();

# %% [markdown]
# ## evaluate and predict
# Now thet we have a model we can use to predict results on the validation dataset.
# 1. What can say about example that fail prediction? can we find patterns that are common for failure cases?

# %%
import seaborn as sbn
predictions = m.predict(val['images'])
sbn.distplot(predictions[:,0]);

predicted_label = np.argmax(predictions, axis=-1)
print ('accuracy:', np.mean(predicted_label==val['labels']))
# Out:
# accuracy: 0.8888888888888888

# %%
viz_my_data(num=(6,6),predictions=predictions[:,1],**val);

# %% [markdown]
# ### Seek ways to improve resutls
# 1. Try to play with diffferent models , increase / decrease the number of conv layers or number of  filters. you'll need to find a balanced model that is sufficiently large but minimzes overfit
#     - try to enable tensorboard vizualization (see keras/ tensorboard doc) to help you carry the analysis
# 2. Data augmentation: feed your network with more examples by using data augmentation techniques: such as horizontal image flip, noise, etc

# %% [markdown]
# ### Saving the model
# After we trained our model and made predictions with it, we will now want to save the **architecture** together with its learned **weights** in order for us to be able to use it in the TFL manager.
# The architecture will be saved as a json, the weights in the h5 format:

# %%
m.save("new_model.h5")

# %%
# If you want to make sure that this model can be used on different operating systems and different
# versions of keras or tensorflow, this is the better way to save. For this project the simpler
# method above should work fine.

# json_filename = 'model.json'
# h5_filename   = 'weights.h5'
# # create a json with the model architecture
# model_json = m.to_json()
# # save the json to disk
# with open(json_filename, 'w') as f:
#     f.write(model_json)
# # save the model's weights:
# m.save_weights(h5_filename)
# print(" ".join(["Model saved to", json_filename, h5_filename]))
# Out:
# Model saved to model.json weights.h5

# %% [markdown]
# ### Loading the model

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model("model.h5")
# Out:
# WARNING:tensorflow:From c:\users\rent\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\rent\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\rent\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\rent\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# If you use the more robust method of saving above, this is how you load the model.

# with open(json_filename, 'r') as j:
#     loaded_json = j.read()

# # load the model architecture: 
# loaded_model = keras.models.model_from_json(loaded_json)
# #load the weights:
# loaded_model.load_weights(h5_filename)
# print(" ".join(["Model loaded from", json_filename, h5_filename]))
# Out:
# Model loaded from model.json weights.h5

# %%
# code copied from the training evaluation: 
l_predictions = loaded_model.predict(val['images'])
sbn.distplot(l_predictions[:,0]);

l_predicted_label = np.argmax(l_predictions, axis=-1)
print ('accuracy:', np.mean(l_predicted_label==val['labels']))
# Out:
# accuracy: 0.8195876288659794
